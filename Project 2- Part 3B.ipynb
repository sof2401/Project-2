# %%
import pandas as pd
import numpy as np

import os 
os.makedirs('Data/', exist_ok=True)

# %%
import sqlite3
conn = sqlite3.connect('movies.db')

# %%
tmdb= pd.read_csv('Data/tmdb.csv.gz')
tmdb.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                                NaN   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
# ...

# %%
tmdb
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                                NaN   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
# ...

# %%
df = pd.read_csv("Data/title.basics.tsv.gz", sep='\t', low_memory=False)
df
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10017006  tt9916848  tvEpisode              Episode #3.17
# 10017007  tt9916850  tvEpisode              Episode #3.19
# 10017008  tt9916852  tvEpisode              Episode #3.20
# 10017009  tt9916856      short                   The Wind
# 10017010  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
filtered_df = df[(df['startYear'] == '2001') | (df['startYear'] == '2002')]
filtered_df
# Out:
#              tconst  titleType                   primaryTitle  \
# 33802     tt0034413      short             Youth Gets a Break
# 34802     tt0035423      movie                 Kate & Leopold
# 92620     tt0094718      short                        Beavers
# 93930     tt0096056      movie           Crime and Punishment
# 104785    tt0107194      short                        Imagine
# ...             ...        ...                            ...
# 10016118  tt9914870  tvEpisode                 Episode #1.967
# 10016119  tt9914872  tvEpisode                 Episode #1.968
# 10016122  tt9914878  tvEpisode                 Episode #1.969
# 10016635  tt9916064  videoGame                      AeroWings
# 10016668  tt9916136  tvEpisode  Episode dated 7 February 2002
#
#                           originalTitle isAdult startYear endYear  \
# 33802                Youth Gets a Break       0      2001      \N
# 34802                    Kate & Leopold       0      2001      \N
# ...

# %%
keep_cols= ['imdb_id','budget','revenue','certification']
TMDB= tmdb[keep_cols]
TMDB
# Out:
#      imdb_id     budget     revenue certification
# 0  tt0848228  220000000  1518815515         PG-13
# 1  tt0848228  220000000  1518815515         PG-13
# 2  tt0332280   29000000   115600000         PG-13

# %%
TMDB['imdb_id']=TMDB['imdb_id'].astype(str)
# Out:
# /var/folders/fc/lxtc0_tj33b65krh167ynf300000gn/T/ipykernel_12333/789625827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TMDB['imdb_id']=TMDB['imdb_id'].astype(str)

# %%
## create a col with a list of genres
filtered_df['genres_split'] = filtered_df['genres'].str.split(',')
filtered_df
# Out:
# /var/folders/fc/lxtc0_tj33b65krh167ynf300000gn/T/ipykernel_12333/98254700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['genres_split'] = filtered_df['genres'].str.split(',')
#              tconst  titleType                   primaryTitle  \
# 33802     tt0034413      short             Youth Gets a Break
# 34802     tt0035423      movie                 Kate & Leopold
# 92620     tt0094718      short                        Beavers
# 93930     tt0096056      movie           Crime and Punishment
# 104785    tt0107194      short                        Imagine
# ...             ...        ...                            ...
# 10016118  tt9914870  tvEpisode                 Episode #1.967
# ...

# %%
exploded_genres = filtered_df.explode('genres_split').astype(str)
exploded_genres
# Out:
#              tconst  titleType                   primaryTitle  \
# 33802     tt0034413      short             Youth Gets a Break
# 34802     tt0035423      movie                 Kate & Leopold
# 34802     tt0035423      movie                 Kate & Leopold
# 34802     tt0035423      movie                 Kate & Leopold
# 92620     tt0094718      short                        Beavers
# ...             ...        ...                            ...
# 10016122  tt9914878  tvEpisode                 Episode #1.969
# 10016122  tt9914878  tvEpisode                 Episode #1.969
# 10016635  tt9916064  videoGame                      AeroWings
# 10016668  tt9916136  tvEpisode  Episode dated 7 February 2002
# 10016668  tt9916136  tvEpisode  Episode dated 7 February 2002
#
#                           originalTitle isAdult startYear endYear  \
# 33802                Youth Gets a Break       0      2001      \N
# 34802                    Kate & Leopold       0      2001      \N
# ...

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
title_genres= exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#           tconst genres_split
# 33802  tt0034413        Short
# 34802  tt0035423       Comedy
# 34802  tt0035423      Fantasy
# 34802  tt0035423      Romance
# 92620  tt0094718  Documentary

# %%
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Documentary': 7,
#  'Drama': 8,
#  'Family': 9,
#  'Fantasy': 10,
#  'Game-Show': 11,
#  'History': 12,
#  'Horror': 13,
#  'Music': 14,
#  'Musical': 15,
#  'Mystery': 16,
#  'News': 17,
#  'Reality-TV': 18,
#  'Romance': 19,
#  'Sci-Fi': 20,
#  'Short': 21,
#  'Sport': 22,
#  'Talk-Show': 23,
#  'Thriller': 24,
#  'War': 25,
#  'Western': 26,
#  '\\N': 27}

# %%
def map_genres(genres_list):
    return [genre_map.get(genre, None) for genre in genres_list]

filtered_df['genre_id'] = filtered_df['genres_split'].apply(map_genres)
filtered_df = filtered_df.drop(columns='genres_split')
# Out:
# /var/folders/fc/lxtc0_tj33b65krh167ynf300000gn/T/ipykernel_12333/916552703.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['genre_id'] = filtered_df['genres_split'].apply(map_genres)

# %%
genre_lookup= pd.DataFrame({'Genre_Name': genre_map.keys(),
                            'Genre_ID': genre_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
#Creating MySQL tables with a primary key using Python

# %%
## get max string length
max_str_len= tmdb['certification'].fillna('').map(len).max()

# %%
from sqlalchemy.types import *

key_len = tmdb['imdb_id'].fillna('').map(len).max()
cert_len = tmdb['certification'].fillna('').map(len).max()

df_schema = {
    "imdb_id": CHAR(), 
    "budget": FLOAT(),
    "revenue": FLOAT(),
    "certification": VARCHAR(cert_len+1)}

# %%
TMDB.dtypes
# Out:
# imdb_id          object
# budget            int64
# revenue           int64
# certification    object
# dtype: object

# %%
TMDB.to_sql('tmdb_data',conn, dtype=df_schema, if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 TMDB.to_sql('tmdb_data',conn, dtype=df_schema, if_exists='replace',index=False)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.10/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# ...

# %%
from sqlalchemy import create_engine

database_path = 'movies.db'

# Create an SQLite engine
engine = create_engine(f'sqlite:///{TMDB}', echo=True)

# %%
with engine.connect() as connection:
    connection.execute('ALTER TABLE TMDB ADD PRIMARY KEY (`imdb_id`);')
