# %%
import pandas as pd
import joblib

# %%
df= joblib.load('ratings_model.joblib')
df.head()
# Out:
#                    review_id  movie_id    imdb_id          original_title  \
# 1   57086ff5c3a3681d29001512      7443  tt0120630             Chicken Run
# 6   57b2d23dc3a36837d7000b14       955  tt0120755  Mission: Impossible II
# 7   5e9120963679a10018375490       955  tt0120755  Mission: Impossible II
# 15  608e2744d8cc4a0058dc4272      2621  tt0122459            Return to Me
# 20  6409202f0e441900e887a17b      4234  tt0134084                Scream 3
#
#                                                review  rating  \
# 1   A guilty pleasure for me personally, as I love...     9.0
# 6   The first underwhelmed me, but this one straig...     3.0
# 7   After quite entertainign Mission Impossible I ...     2.0
# 15  Okay, I will admit I can be a bit of an easy g...     9.0
# 20  **_Scream 3’s_ lackluster screenplay and unima...     4.0
#
#                                                tokens       target  \
# 1   A guilty pleasure for me personally, as I love...  High-rating
# 6   The first underwhelmed me, but this one straig...   Low-rating
# 7   After quite entertainign Mission Impossible I ...   Low-rating
# 15  Okay, I will admit I can be a bit of an easy g...  High-rating
# 20  **_Scream 3’s_ lackluster screenplay and unima...   Low-rating
#
#                                             Tokenized  \
# 1   [A, guilty, pleasure, for, me, personally,, as...
# 6   [The, first, underwhelmed, me,, but, this, one...
# 7   [After, quite, entertainign, Mission, Impossib...
# 15  [Okay,, I, will, admit, I, can, be, a, bit, of...
# 20  [**_Scream, 3’s_, lackluster, screenplay, and,...
#
#                                            Lemmatized  \
# 1   [guilty, pleasure, personally, love, the, Grea...
# 6   [the, underwhelme, straight, bore, of, course,...
# 7   [entertainign, Mission, Impossible, the, secon...
# 15  [okay, admit, be, bit, of, easy, grader, come,...
# 20  [Scream, 3, lackluster, screenplay, unimaginat...
#
#                                         Tokens-joined  \
# 1   A guilty pleasure for me personally, as I love...
# 6   The first underwhelmed me, but this one straig...
# 7   After quite entertainign Mission Impossible I ...
# 15  Okay, I will admit I can be a bit of an easy g...
# 20  **_Scream 3’s_ lackluster screenplay and unima...
#
#                                         Lemmas-joined
# 1   guilty pleasure personally love the Great Esca...
# 6   the underwhelme straight bore of course see Hu...
# 7   entertainign Mission Impossible the second ins...
# 15  okay admit be bit of easy grader come to roman...
# 20  Scream 3 lackluster screenplay unimaginative k...

# %%
df['rating'].isnull().sum()
# Out:
# 0

# %%
X= 'review'
y= 'target'

# %%
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import LabelEncoder
from sklearn import set_config
set_config(transform_output='pandas')
pd.set_option('display.max_colwidth', 250)
